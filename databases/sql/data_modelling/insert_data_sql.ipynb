# %%
# Importando as libs
import pandas as pd
from sqlalchemy import create_engine

# %%
# Lendo todos os dados
customers    = pd.read_csv('olist_customers_dataset.csv')
orders_items = pd.read_csv('olist_order_items_dataset.csv')
orders       = pd.read_csv('olist_orders_dataset.csv')

# %%
# Juntando dodas as tabelas em uma tabela denormalizada
merged = orders.merge(customers,on='customer_id')\
    .merge(orders_items,on='order_id')

# %% [markdown]
# ## Conectando ao banco sql

# %%
engine = create_engine('postgresql://postgres:mysecretpassword@127.0.0.1:5432/postgres')

# %%
# TEstando a conexão com o banco de dados
customers.to_sql('customers',engine,index=False,if_exists='append')
orders.drop_duplicates(subset=['order_id']).to_sql("orders",engine,index=False,if_exists='append')
orders_items.drop_duplicates(subset=['order_id']).to_sql("order_itens",engine,index=False,if_exists='append')

# %% [markdown]
# # Loading the other data

# %%
order_items_dataset = pd.read_csv("./data/olist_order_items_dataset.csv")
customers_dataset   = pd.read_csv("./data/olist_customers_dataset.csv")
orders_dataset = pd.read_csv("./data/olist_orders_dataset.csv")
products_dataset    = pd.read_csv("./data/olist_products_dataset.csv")
geolocation_dataset = pd.read_csv("./data/olist_geolocation_dataset.csv")
order_payments_dataset = pd.read_csv("./data/olist_order_payments_dataset.csv")
product_category_name_translation = pd.read_csv("./data/product_category_name_translation.csv")
order_reviews_dataset = pd.read_csv("./data/olist_order_reviews_dataset.csv")
sellers_dataset = pd.read_csv("./data/olist_sellers_dataset.csv")

# %%
# for file in os.listdir('data'):
#     variable_name = file.replace('.csv','').replace('olist_','')
#     table_name    = variable_name.replace('_dataset','')
#     print('%s.to_sql("%s",engine,index=False)'%(variable_name,table_name))
    
products_dataset.to_sql("products",engine,if_exists='append',index=False)
geolocation_dataset.to_sql("geolocation",engine,if_exists='append',index=False)
customers_dataset.to_sql("customers",engine,if_exists='append',index=False)
orders_dataset.to_sql("orders",engine,if_exists='append',index=False)
order_items_dataset.to_sql("order_items",engine,if_exists='append',index=False)
order_payments_dataset.to_sql("order_payments",engine,if_exists='append',index=False)
product_category_name_translation.to_sql("product_category_name_translation",engine,if_exists='append',index=False)
order_reviews_dataset.to_sql("order_reviews",engine,if_exists='append',index=False)
sellers_dataset.to_sql("sellers",engine,if_exists='append',index=False)
# Out:
# ---------------------------------------------------------------------------
# UniqueViolation                           Traceback (most recent call last)
# ~/Documents/code/mentoria/venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1685                 if not evt_handled:
# -> 1686                     self.dialect.do_executemany(
#    1687                         cursor, statement, parameters, context
#
# ~/Documents/code/mentoria/venv/lib/python3.9/site-packages/sqlalchemy/dialects/postgresql/psycopg2.py in do_executemany(self, cursor, statement, parameters, context)
#     902             xtras = self._psycopg2_extras()
# --> 903             context._psycopg2_fetched_rows = xtras.execute_values(
#     904                 cursor,
#
# ...

# %%
products_dataset
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
# ...
